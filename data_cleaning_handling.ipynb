# %% [markdown]
# Remove 44 duplicate records

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Handled null values

# %%
df["Health_Impacts"] = df["Health_Impacts"].fillna("No Reported Issues")

# %%
df.isnull().sum()
# Out:
# Age                                  0
# Gender                               0
# Avg_Daily_Screen_Time_hr             0
# Primary_Device                       0
# Exceeded_Recommended_Limit           0
# Educational_to_Recreational_Ratio    0
# Health_Impacts                       0
# Urban_or_Rural                       0
# dtype: int64
